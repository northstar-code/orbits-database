# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
from dynamicslib.common import *
from dynamicslib.consts import *
from dynamicslib.continuation import *
from dynamicslib.targeter import *
from dynamicslib.plotting import *
import pandas as pd
from tqdm import tqdm
import os

# %%
root = os.getcwd() + "/"
file = "L1 Halo.csv"

params = [
    "Initial x",
    "Initial y",
    "Initial z",
    "Initial vx",
    "Initial vy",
    "Initial vz",
]

# %%
csv_data = pd.read_csv(root + file)
csv_indexed = csv_data.set_index("Index")
cols = csv_indexed.columns.tolist()


def row2X(row):
    X = []
    for j, Xj in enumerate(row):
        if cols[j] in params:
            X.append(Xj)
    # if cols[j] == "Period"
    X.append(row[cols.index("Period")])

    return X


def X2xtf(X):
    x0 = np.zeros(6)
    for j, Xj in enumerate(X):
        if cols[j] in params:
            x0[params.index(cols[j])] = Xj
    return x0, X[-1]


def f1(*args):
    return None


plot_params = ["Index", "Period", "Jacobi Constant", "Stability Index"]
data = csv_data[plot_params].values
xyzs = []

iterator = list(enumerate(csv_indexed.values))
for i, row in tqdm(iterator):
    X = row2X(row)
    x0, tf = X2xtf(X)
    xyzs.append(prop_ic(X, X2xtf, int_tol=1e-10))

# %%
# import matplotlib.pyplot as plt

# %%
# fig = plt.figure(figsize=(11, 5))
# axs = fig.subplots(1, 2)

# a = 0
# b = 600
# c = 30

# subdf = csv_data.iloc[a:b:c]


# # eigs = data[:300:10, -6:]
# eigs = (
#     csv_data[[col for col in csv_data.columns if "Eig" in col]]
#     .astype(np.complex128)
#     .values
# )
# eigs = eigs[a:b:c]
# xs = subdf["Jacobi Constant"].values
# eig_rl = eigs.copy()
# eig_cplx = eigs.copy()
# isrl = np.logical_or(np.abs(eigs) > 1.01, 1 / np.abs(eigs) > 1.01)
# eig_rl[np.logical_not(isrl)] = np.nan
# eig_cplx[isrl] = np.nan
# axs[0].scatter(np.real(eig_cplx.T), np.imag(eig_cplx.T), c=list(xs) * 6, cmap="rainbow")
# for jj in range(len(eig_cplx)):
#     for kk in range(6):
#         axs[0].text(np.real(eig_cplx[jj, kk]), np.imag(eig_cplx[jj, kk]), f"{jj+1}")
#         axs[1].text(jj, np.abs(eig_rl[jj, kk]), f"{jj+1}")
# axs[0].axis("equal")
# sc = axs[1].scatter(
#     list(range(len(xs))) * 6, np.abs(eig_rl.T), c=list(xs) * 6, cmap="rainbow"
# )
# axs[1].set_yscale("log")
# axs[0].grid(True)
# axs[1].grid(True)
# axs[0].set(
#     xlabel=r"$\Re \lambda$", ylabel=r"$\Im \lambda$", title="eigs near unit circle"
# )
# axs[1].set(xticks=[], xlabel="index", ylabel=r"$\Im \lambda$", title="real eigs")
# plt.colorbar(sc, label="JC [nd]")
# plt.tight_layout()
# subdf["index"] = np.arange(len(xs)) + 1
# subdf

# %%
a = None
b = None
c = 1
plotly_display(xyzs[a:b:c], csv_data[a:b:c], port=8003)
